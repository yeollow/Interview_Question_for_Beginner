# %% [markdown]
# <a href="https://colab.research.google.com/github/yeollow/Interview_Question_for_Beginner/blob/master/computervision_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2016110556 이정열

# %%
! git clone https://github.com/soonkijung/cv-datasets
# Out:
# Cloning into 'cv-datasets'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 40 (delta 11), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %%
import numpy as np
from matplotlib import pyplot as plt 

from skimage import io
from skimage import color
from skimage import img_as_float32

# %%
#assignment 1

# 1920 * 1080
image = np.zeros((1080,1920,3))

#green random
image[:,0:960,1] = np.random.randint(2,size=(1080,960))

#red random
image[0:200,:,0] = np.random.randint(2,size=(200,1920))

#yeollow area
image[200:1080,960:1500,0]=1
image[200:1080,960:1500,1]=1

#black area inside the yellow area
image[200:400,960:1250,0]=0
image[200:400,960:1250,1]=0
image[200:400,960:1250,2]=0

#blue area inside the yellow area
image[500:600,1100:1400,0]=0
image[500:600,1100:1400,1]=0
image[500:600,1100:1400,2]=1

#green area
image[200:800,1500:1920,1] = 1

#cyan area inside the green area
image[500:600,1600:1800,2] = 1

plt.imshow(image)
plt.show()

# %%
image = io.imread('/content/cv-datasets/Notre_Dame_1.jpg')
plt.imshow(image)

# %%
(m,n,o) = image.shape

RED = image[:,:,0]
GREEN = image[:,:,1]
BLUE = image[:,:,2]

BLACK = np.zeros((m,n),dtype = np.uint8)

redImage = np.stack((RED,BLACK,BLACK),axis=2)
greenImage = np.stack((BLACK,GREEN,BLACK),axis=2)
blueImage = np.stack((BLACK,BLACK,BLUE),axis=2)

plt.imshow(redImage)

plt.show()

plt.imshow(greenImage)
plt.show()

plt.imshow(blueImage)
plt.show()

recombinedImage = np.stack((RED,GREEN,BLUE),axis=2)
plt.imshow(recombinedImage)

# %%
image[300:,0:100,1]=0
image[300:,0:100,2]=0


image[300:,100:300,0]=0
image[300:,100:300,2]=0

image[300:,300:,0]=0
image[300:,300:,1]=0


plt.imshow(image)
